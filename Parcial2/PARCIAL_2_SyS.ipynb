# %% [markdown]
# <a href="https://colab.research.google.com/github/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/PARCIAL_2_SyS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SOLUCION PARCIAL 2, SyS**
#
# # **Presentado por:** *Marlyn Nathalia Mora Riascos*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ⭐ En el siguiente enlace se encuentra el archivo .pdf con la solución teórica del espectro de Fourier en cada una de las etapas ▶:
#
# https://github.com/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/Punto1__parcial_2_modulaci%C3%B3n_AM_.ipynb
#
# # ⭐ En este enlace se encuentra la solución desarrollada en Google Colab ▶:
#
# https://github.com/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/punto%201%20teoria%20sys.pdf
#
# # ⭐ En este enlace se encuentra la solución implementada en el dashboard ▶:
#
# https://github.com/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/Dashboard_1.ipynb

# %% [markdown]
# # 🔵 2. Encuentre la función de transferencia que caracteriza el sistema masa, resorte, amortiguador, presentado en la siguiente Figura (asuma condiciones iniciales cero):
#
# ![image.png](data:image/png;base64,...)
#
# # Posteriormente, encuentre el sistema equivalente del modelo masa, resorte, amortiguador, a partir del siguiente circuito eléctrico:
#
# ![image.png](data:image/png;base64,...)
#
# # Finalmente, proponga unos valores de $m$, $k$ y $c$ y sus equivalentes $R$, $L$ y $C$, para simular un sistema subamortiguado, sobreamortiguado y de amortiguamiento crítico (determine el factor de amortiguamiento, la frecuencia natural amortiguada, la frecuencia natural no amortiguada, el tiempo pico, tiempo de levantamiento y el tiempo de establecimiento en cada caso). Para cada caso, grafique el diagrama de polos y ceros, el diagrama de Bode, la respuesta impulso, respuesta escalón y respuesta rampa. Repita el proceso para modo lazo cerrado.

# %% [markdown]
# # ⭐ En el siguiente enlace se encuentra el archivo .pdf con la solución teórica del espectro de Fourier en cada una de las etapas ▶:
# https://github.com/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/punto%202%20.pdf
#
#
# # ⭐ En este enlace se encuentra la solución desarrollada en Google Colab ▶:
# https://github.com/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/solucionPunto2.ipynb
#
#
# # ⭐ En este enlace se encuentra la solución implementada en el dashboard ▶:
# https://github.com/mmorari-cmyk/CURSO_SE.ALES_Y_SISTEMAS/blob/main/Parcial2/DASHBOARD_2.ipynb
